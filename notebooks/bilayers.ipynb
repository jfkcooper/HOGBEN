# %% [markdown]
# # Experimental Design
# ***
# ## Lipid Bilayers

# %% [markdown]
# Import the necessary packages and code to generate the bilayer results.

# %%
# %matplotlib inline

import numpy as np
import sys

# For copying the model when sampling.
from copy import deepcopy

# Code for optimising and visualising.
from hogben.optimise import Optimiser
from hogben.visualise import contrast_choice_single, contrast_choice_double, underlayer_choice

# Bilayer models.
from hogben.models.bilayers import BilayerDMPC, BilayerDPPC

# Reduce size of plots for the notebook.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,5)
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# Select the bilayer model to generate results for: either the 1,2-dimyristoyl-sn-glycero-3-phosphocholine (DMPC) or the 1,2-dipalmitoyl-sn-glycero-3-phosphocholine (DPPC) / lipopolysaccharide (LPS) bilayer.
#
# This cell will also get the fitted SLD profile and reflectivity curve for the experimentally-measured data sets of the chosen model.

# %%
bilayer = BilayerDMPC() # Options are BilayerDMPC or BilayerDPPC.

save_path = './results'
bilayer.sld_profile(save_path)
bilayer.reflectivity_profile(save_path)

# %% [markdown]
# ### Contrast Choice
# ***
# Get the plot of minimum eigenvalue versus bulk water contrast SLD, for the chosen bilayer model, for the simultaneous choice of two contrasts assuming no prior measurement.

# %%
# Number of points and counting times for each angle to simulate.
angle_times = [(0.7, 100, 10),
               (2.3, 100, 40)]

# Change the number of points in the contrast range to increase/decrease detail of the plot.
contrast_range = np.linspace(-0.56, 6.36, 5)
contrast_choice_double(bilayer, contrast_range, angle_times, save_path)

# Adjust the viewing angle of the 3D plot.
ax = plt.gca()
ax.view_init(elev=40, azim=50)
# Out:
# >>> 0/10

# %% [markdown]
# Get the nested sampling corner plots from sampling simulated data of solely D2O, and simulated data of D2O and H2O.

# %%
bilayer_copy = deepcopy(bilayer)
bilayer_copy.nested_sampling([6.36, 6.36], angle_times, save_path, 'D2O_D2O')
bilayer_copy.nested_sampling([-0.56, 6.36], angle_times, save_path, 'H2O_D2O')
# Out:
# 9357it [94:20:55, 91.68s/it, bound: 12022 | nc: 199 | ncall: 9035284 | eff(%):  0.104 | loglstar:   -inf < 3397.462 <    inf | logz: 3379.511 +/-  0.181 | dlogz:  1.907 >  0.509]     Traceback (most recent call last):
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/dynesty.py", line 910, in __call__
#     return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/analysis/objective.py", line 1183, in logl
#     logl += _lambda * objective.logl()
#                       ^^^^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/analysis/objective.py", line 645, in logl
#     model = self.model(self.data.x, x_err=self.data.x_err)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py", line 385, in __call__
#     return self.model(x, p=p, x_err=x_err)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py", line 481, in model
#     return reflectivity(
#            ^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py", line 634, in reflectivity
#     scale * _smeared_kernel_constant(q, slabs, dq, threads=threads)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py", line 893, in _smeared_kernel_constant
#     smeared_rvals = np.convolve(rvals, gauss_y, mode="same")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 200, in convolve
#   File "/Users/joshanielcooper/anaconda3/envs/Hogben/lib/python3.11/site-packages/numpy/core/numeric.py", line 755, in convolve
#     @array_function_dispatch(_convolve_dispatcher)
#
# KeyboardInterrupt
# 9357it [94:21:39, 36.30s/it, bound: 12022 | nc: 199 | ncall: 9035284 | eff(%):  0.104 | loglstar:   -inf < 3397.462 <    inf | logz: 3379.511 +/-  0.181 | dlogz:  1.907 >  0.509]
# Exception while calling loglikelihood function:
#   params: [ 4.01288431 12.09413699  3.19782843  0.85982862 49.59401032  7.03071148
#   0.05671683  1.40607143]
#   args: []
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 bilayer_copy = deepcopy(bilayer)
# ----> 2 bilayer_copy.nested_sampling([6.36, 6.36], angle_times, save_path, 'D2O_D2O')
#       3 bilayer_copy.nested_sampling([-0.56, 6.36], angle_times, save_path, 'H2O_D2O')
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/hogben/models/base.py:445, in BaseLipid.nested_sampling(self, contrasts, angle_times, save_path, filename, underlayers, dynamic)
#     443 # Sample the objective using nested sampling.
#     444 sampler = Sampler(global_objective)
# --> 445 fig = sampler.sample(dynamic=dynamic)
#     447 # Save the sampling corner plot.
#     448 save_path = os.path.join(save_path, self.name)
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/hogben/utils.py:65, in Sampler.sample(self, verbose, dynamic)
#      62     results = self.sampler_dynamic.results
#      64 else:
# ---> 65     self.sampler_static.run_nested(print_progress=verbose)
#      66     results = self.sampler_static.results
#      68 # Calculate the parameter means.
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampler.py:1017, in Sampler.run_nested(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, print_progress, print_func, save_bounds, checkpoint_file, checkpoint_every, resume)
#    1015 try:
#    1016     ncall = self.ncall
# -> 1017     for it, results in enumerate(
#    1018             self.sample(maxiter=maxiter,
#    1019                         maxcall=maxcall,
#    1020                         dlogz=dlogz,
#    1021                         logl_max=logl_max,
#    1022                         save_bounds=save_bounds,
#    1023                         save_samples=True,
#    1024                         n_effective=n_effective,
#    1025                         resume=resume,
#    1026                         add_live=add_live)):
#    1027         ncall += results.nc
#    1029         # Print progress.
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampler.py:840, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples, resume)
#     835     old_blob = None
#     837 # Sample a new live point from within the likelihood constraint
#     838 # `logl > loglstar` using the bounding distribution and sampling
#     839 # method from our sampler.
# --> 840 u, v, logl, nc = self._new_point(loglstar_new)
#     841 ncall += nc
#     842 self.ncall += nc
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampler.py:421, in Sampler._new_point(self, loglstar)
#     418 ncall_accum = 0
#     419 while True:
#     420     # Get the next point from the queue
# --> 421     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     422     ncall += nc
#     423     ncall_accum += nc
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampler.py:404, in Sampler._get_point_value(self, loglstar)
#     402 # If the queue is empty, refill it.
#     403 if self.nqueue <= 0:
# --> 404     self._fill_queue(loglstar)
#     406 # Grab the earliest entry.
#     407 u, v, logl, nc, blob = self.queue.pop(0)
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampler.py:397, in Sampler._fill_queue(self, loglstar)
#     387 for i in range(self.queue_size):
#     388     args.append(
#     389         SamplerArgument(u=point_queue[i],
#     390                         loglstar=loglstar,
#    (...)
#     395                         rseed=seeds[i],
#     396                         kwargs=self.kwargs))
# --> 397 self.queue = list(mapper(evolve_point, args))
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/sampling.py:88, in sample_unif(args)
#      84 # Unzipping.
#      85
#      86 # Evaluate.
#      87 v = args.prior_transform(np.asarray(args.u))
# ---> 88 logl = args.loglikelihood(np.asarray(v))
#      89 nc = 1
#      90 blob = None
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/utils.py:187, in LogLikelihood.__call__(self, x)
#     183 def __call__(self, x):
#     184     """
#     185     Evaluate the likelihood f-n once
#     186     """
# --> 187     ret = LoglOutput(self.loglikelihood(x), self.blob)
#     188     if self.save:
#     189         self.history_append([ret.val], [x])
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/dynesty/dynesty.py:910, in _function_wrapper.__call__(self, x)
#     902 def __call__(self, x):
#     903     try:
#     904         # IMPORTANT
#     905         # Here we make a copy if the input vector just to ensure
#    (...)
#     908         # This comes at performance cost, but it's worthwhile
#     909         # as it may lead to hard to diagnose weird behaviour
# --> 910         return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#     911     except:  # noqa
#     912         print(f"Exception while calling {self.name} function:")
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/analysis/objective.py:1183, in GlobalObjective.logl(self, pvals)
#    1180 logl = 0.0
#    1182 for objective, _lambda in zip(self.objectives, self.lambdas):
# -> 1183     logl += _lambda * objective.logl()
#    1185 return logl
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/analysis/objective.py:645, in Objective.logl(self, pvals)
#     608 """
#     609 Calculate the log-likelhood of the system
#     610
#    (...)
#     641
#     642 """
#     643 self.setp(pvals)
# --> 645 model = self.model(self.data.x, x_err=self.data.x_err)
#     647 logl = 0.0
#     649 y, y_err, model = self._data_transform(model)
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py:385, in ReflectModel.__call__(self, x, p, x_err)
#     366 def __call__(self, x, p=None, x_err=None):
#     367     r"""
#     368     Calculate the generative model
#     369
#    (...)
#     383         Calculated reflectivity
#     384     """
# --> 385     return self.model(x, p=p, x_err=x_err)
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py:481, in ReflectModel.model(self, x, p, x_err)
#     477 if x_err is None or self.dq_type == "constant":
#     478     # fallback to what this object was constructed with
#     479     x_err = float(self.dq)
# --> 481 return reflectivity(
#     482     x + self.q_offset.value,
#     483     self.structure.slabs()[..., :4],
#     484     scale=self.scale.value,
#     485     bkg=self.bkg.value,
#     486     dq=x_err,
#     487     threads=self.threads,
#     488     quad_order=self.quad_order,
#     489 )
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py:634, in reflectivity(q, slabs, scale, bkg, dq, quad_order, threads)
#     631 elif isinstance(dq, numbers.Real):
#     632     dq = float(dq)
#     633     return (
# --> 634         scale * _smeared_kernel_constant(q, slabs, dq, threads=threads)
#     635     ) + bkg
#     637 # point by point resolution smearing (each q point has different dq/q)
#     638 if isinstance(dq, np.ndarray) and dq.size == q.size:
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/refnx/reflect/reflect_model.py:893, in _smeared_kernel_constant(q, w, resolution, threads)
#     890 gauss_y = gauss(gauss_x, resolution / _FWHM)
#     892 rvals = kernel(xlin, w, threads=threads)
# --> 893 smeared_rvals = np.convolve(rvals, gauss_y, mode="same")
#     894 smeared_rvals *= gauss_x[1] - gauss_x[0]
#     896 # interpolator = InterpolatedUnivariateSpline(xlin, smeared_rvals)
#     897 #
#     898 # smeared_output = interpolator(q)
#
# File <__array_function__ internals>:200, in convolve(*args, **kwargs)
#
# File ~/anaconda3/envs/Hogben/lib/python3.11/site-packages/numpy/core/numeric.py:755, in convolve(a, v, mode)
#     751 def _convolve_dispatcher(a, v, mode=None):
#     752     return (a, v)
# --> 755 @array_function_dispatch(_convolve_dispatcher)
#     756 def convolve(a, v, mode='full'):
#     757     """
#     758     Returns the discrete, linear convolution of two one-dimensional sequences.
#     759
#    (...)
#     842
#     843     """
#     844     a, v = array(a, copy=False, ndmin=1), array(v, copy=False, ndmin=1)
#
# KeyboardInterrupt:

# %% [markdown]
# Get the plot of minimum eigenvalue versus bulk water contrast SLD for the chosen bilayer model, for a third contrast choice, assuming D2O and H2O have been previously measured.
#
# This plot may look slightly different to the one shown in the paper as here we assume D2O and H2O have been measured for equal times.

# %%
contrast_range = np.linspace(-0.56, 6.36, 100)
contrast_choice_single(bilayer, contrast_range, [-0.56, 6.36], angle_times, save_path, 'H2O_D2O')

# %% [markdown]
# Using differential evolution, optimise the contrast SLDs and counting time splits, for the chosen bilayer model, using a given number of contrasts.

# %%
# Number of contrasts to optimise.
num_contrasts = 2

# Range of contrasts to optimise over.
contrast_bounds = (-0.56, 6.36)

# Counting time splits between angles to simulate.
angle_splits = [(0.7, 100, 0.2),
                (2.3, 100, 0.8)]

optimiser = Optimiser(bilayer)
contrasts, splits, val = optimiser.optimise_contrasts(num_contrasts, angle_splits,
                                                      contrast_bounds=contrast_bounds, verbose=False)
# Convert to percentages.
splits = np.array(splits)*100

# Round the optimisation function value to 4 significant figures.
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('Contrasts: {}'.format(list(np.round(contrasts, 2))))
print('Time Splits (%): {}'.format(list(np.round(splits, 1))))
print('Objective value: {}'.format(val))

# %% [markdown]
# ### Angle Choice
# ***
# Using differential evolution, optimise the angles and counting time splits, for the chosen bilayer model, using a given number angles.

# %%
# Number of angles to optimise.
num_angles = 2

# Contrasts to use when simulating.
contrasts = [-0.56, 6.36]

# Range of angles to optimise over.
angle_bounds = (0.2, 4.0)

angles, splits, val = optimiser.optimise_angle_times(num_angles, contrasts,
                                                     angle_bounds=angle_bounds, verbose=False)
# Convert to percentages.
splits = np.array(splits)*100

# Round the optimisation function value to 4 significant figures.
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('Angles: {}'.format(list(np.round(angles, 2))))
print('Time Splits (%): {}'.format(list(np.round(splits, 1))))
print('Objective value: {}'.format(val))

# %% [markdown]
# ### Underlayer Choice
# ***
# Get the plot of minimum eigenvalue versus underlayer SLD and underlayer thickness, for the chosen bilayer model, assuming D2O and H2O are being measured.

# %%
# Contrasts to simulate.
contrasts = [-0.56, 6.36]

# Range of thicknesses and SLDs to visualise over.
# Change the number of points to increase/decrease detail of the plot.
thickness_range = np.linspace(5, 500, 25)
sld_range = np.linspace(1, 9, 5)

underlayer_choice(bilayer, thickness_range, sld_range, contrasts, angle_times, save_path, 'D2O_H2O')

# Adjust the viewing angle of the 3D plot.
ax = plt.gca()
ax.view_init(elev=40, azim=230)

# %% [markdown]
# Get the nested sampling corner plots from sampling simulated data of D2O and H2O without any underlayer and with a single underlayer.

# %%
# No underlayer.
bilayer_copy.nested_sampling([-0.56, 6.36], [(0.7, 100, 40)], save_path, 'D2O_H2O_without_underlayer', underlayers=[]);

# Select the appropriate optimal underlayer.
if isinstance(bilayer, BilayerDMPC):
    underlayers = [(127.1, 5.39)] # Optimal DMPC bilayer underlayer.
elif isinstance(bilayer, BilayerDPPC):
    underlayers = [(76.5, 9.00)] # Optimal DPPC/Ra LPS bilayer underlayer.
else:
    raise RuntimeError('Invalid bilayer model')
    
bilayer_copy.nested_sampling([-0.56, 6.36], [(0.7, 100, 40)], save_path, 'D2O_H2O_with_underlayer', underlayers=underlayers);

# %% [markdown]
# Calculate the minimum eigenvalue without any underlayers.

# %%
# Calculate the objective value using no underlayers.
fisher = bilayer.underlayer_info(angle_times, contrasts, [])
val = -fisher.min_eigenval
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('------------ No Underlayer ------------')
print('Objective value: {}'.format(val))

# %% [markdown]
# Calculate the minimum eigenvalue using gold and Permalloy underlayers.

# %%
# Calculate the objective value using gold underlayer.
underlayer = [(100, 4.7)]
fisher = bilayer.underlayer_info(angle_times, contrasts, [])
val = -fisher.min_eigenval
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('------------ Au Underlayer ------------')
print('Thicknesses: {}'.format([underlayer[0][0]]))
print('SLDs: {}'.format([underlayer[0][1]]))
print('Objective value: {}\n'.format(val))

# Calculate the objective value using a Permalloy underlayer.
underlayer = [(100, 8.4)]
fisher = bilayer.underlayer_info(angle_times, contrasts, [])
val = -fisher.min_eigenval
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('--------- Permalloy Underlayer --------')
print('Thicknesses: {}'.format([underlayer[0][0]]))
print('SLDs: {}'.format([underlayer[0][1]]))
print('Objective value: {}'.format(val))

# %% [markdown]
# Using differential evolution, optimise the underlayer SLDs and thicknesses, for the chosen bilayer model, using a given number of underlayers.

# %%
# Number of underlayers to optimise.
num_underlayers = 2

# Range of thicknesses and SLDs to optimise over.
thick_bounds = (0, 500)
sld_bounds = (1, 9)

thicknesses, slds, val = optimiser.optimise_underlayers(num_underlayers, angle_times, contrasts,
                                                        thick_bounds, sld_bounds, verbose=False)

# Round the optimisation function value to 4 significant figures.
val = np.format_float_positional(val, precision=4, unique=False, fractional=False, trim='k')

print('------------ {} Underlayers ------------'.format(num_underlayers))
print('Thicknesses: {}'.format(list(np.round(thicknesses, 1))))
print('SLDs: {}'.format(list(np.round(slds, 2))))
print('Objective value: {}'.format(val))
